# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.3.0-py3-none-any.whl (981 kB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Collecting trio~=0.17
#   Using cached trio-0.21.0-py3-none-any.whl (358 kB)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)Note: you may need to restart the kernel to use updated packages.
#
# Collecting outcome
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sniffio in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.13.0 outcome-1.2.0 selenium-4.3.0 trio-0.21.0 trio-websocket-0.9.2 wsproto-1.1.0

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from pprint import pprint

# %%
browser = webdriver.Chrome()

# %%
browser.get("https://www.starbucks.co.kr/menu/drink_list.do")

# %%
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
products = soup.select('.product_list dd a')

pprint(products)
# Out:
# [<a class="goDrinkView" href="javascript:void(0)" prod="9200000002487"><img alt="나이트로 바닐라 크림" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002487]_20210426091745467.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000479"><img alt="나이트로 콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000479]_20210426091843897.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002081"><img alt="돌체 콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002081]_20210415133656839.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000487"><img alt="바닐라 크림 콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000487]_20210430112319040.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003509"><img alt="벨벳 다크 모카 나이트로" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/03/[9200000003509]_20210322093452399.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003661"><img alt="시그니처 더 블랙 콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/08/[9200000003661]_20210819094346176.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002672"><img alt="제주 비자림 콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/03/[9200000002672]_20220311105511600.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000038"><img alt="콜드 브루" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000038]_20210430113202458.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001636"><img alt="콜드 브루 몰트" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001636]_20210225093600536.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003285"><img alt="콜드 브루 오트 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000003285]_20210416154437069.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001635"><img alt="콜드 브루 플로트" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001635]_20210225092236748.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="106509"><img alt="아이스 커피" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[106509]_20210430111852870.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="2"><img alt="오늘의 커피" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[2]_20210430111934117.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002259"><img alt="블랙 글레이즈드 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000002259]_20220819134201192.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002262"><img alt="아이스 블랙 글레이즈드 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000002262]_20220819134241498.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="30"><img alt="에스프레소 콘 파나" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[30]_20210415144252244.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="25"><img alt="에스프레소 마키아또" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[25]_20210415144211211.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110563"><img alt="아이스 카페 아메리카노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110563]_20210426095937808.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="94"><img alt="카페 아메리카노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[94]_20210430103337006.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110582"><img alt="아이스 카라멜 마키아또" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110582]_20210415142706078.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="126197"><img alt="카라멜 마키아또" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[126197]_20210415154609863.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110601"><img alt="아이스 카푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110601]_20210415143400773.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="38"><img alt="카푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[38]_20210415154821846.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004119"><img alt="라벤더 카페 브레베" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004119]_20220412083025862.png"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001086"><img alt="럼 샷 코르타도" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001086]_20210225090838931.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001939"><img alt="바닐라 빈 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001939]_20210225094313315.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002095"><img alt="사케라또 비안코 오버 아이스" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000002095]_20210225095033382.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="128692"><img alt="스타벅스 돌체 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[128692]_20210426091933665.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004120"><img alt="아이스 라벤더 카페 브레베" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004120]_20220412082952150.png"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001941"><img alt="아이스 바닐라 빈 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001941]_20210225094346653.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="128695"><img alt="아이스 스타벅스 돌체 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[128695]_20210426092031969.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110569"><img alt="아이스 카페 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110569]_20210415143035989.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="41"><img alt="카페 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[41]_20210415133833725.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110566"><img alt="아이스 카페 모카" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110566]_20210415134334280.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110572"><img alt="아이스 화이트 초콜릿 모카" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110572]_20210415155545375.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="46"><img alt="카페 모카" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[46]_20210415134438165.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="128192"><img alt="화이트 초콜릿 모카" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[128192]_20210415155639126.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002406"><img alt="바닐라 플랫 화이트" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002406]_20210415135507733.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110612"><img alt="바닐라 스타벅스 더블 샷" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110612]_20210415133425373.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002950"><img alt="블론드 바닐라 더블 샷 마키아또" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002950]_20210426150654756.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003505"><img alt="사케라또 아포가토" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/03/[9200000003505]_20210322093241535.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003506"><img alt="스파클링 시트러스 에스프레소" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/03/[9200000003506]_20210322093317854.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002953"><img alt="아이스 블론드 바닐라 더블 샷 마키아또" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002953]_20210427132718157.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="20"><img alt="에스프레소" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[20]_20210415144112678.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110611"><img alt="커피 스타벅스 더블 샷" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110611]_20210415132507539.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001631"><img alt="클래식 아포가토" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/02/[9200000001631]_20210225090916684.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110614"><img alt="헤이즐넛 스타벅스 더블 샷" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110614]_20210415132333109.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002760"><img alt="더블 에스프레소 칩 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002760]_20210415133558068.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168004"><img alt="모카 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168004]_20210415134634723.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168007"><img alt="에스프레소 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168007]_20210415144337428.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168016"><img alt="자바 칩 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168016]_20210415154152122.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168010"><img alt="카라멜 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168010]_20210415154711116.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168013"><img alt="화이트 초콜릿 모카 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168013]_20210415155746379.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168054"><img alt="바닐라 크림 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168054]_20210415135751840.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002088"><img alt="제주 까망 크림 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000002088]_20200921171733532.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002090"><img alt="제주 쑥떡 크림 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/03/[9200000002090]_20220329144732789.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002502"><img alt="제주 유기농 말차로 만든 크림 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002502]_20210426100408048.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="168066"><img alt="초콜릿 크림 칩 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[168066]_20210415154429750.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002403"><img alt="화이트 타이거 프라푸치노" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002403]_20210419131548656.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="167004"><img alt="망고 패션 프루트 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[167004]_20210419130801597.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003276"><img alt="딸기 딜라이트 요거트 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000003276]_20210416154001403.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003660"><img alt="레드 파워 스매시 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/08/[9200000003660]_20210805164133783.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="169001"><img alt="망고 바나나 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[169001]_20210419130701792.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003443"><img alt="민트 초콜릿 칩 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000003443]_20210416154107695.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003997"><img alt="제주 그린 한라봉 모히또 블렌디드" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/03/[9200000003997]_20220311105602098.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003763"><img alt="딸기 아사이 레모네이드 스타벅스 리프레셔" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000003763]_20220803131322551.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003766"><img alt="핑크 드링크 위드 딸기 아사이 스타벅스 리프레셔" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000003766]_20220803130957907.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="107025"><img alt="블랙 티 레모네이드 피지오" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[107025]_20210419104756955.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004121"><img alt="유자 패션 피지오" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/05/[9200000004121]_20220517102911610.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="107051"><img alt="쿨 라임 피지오" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[107051]_20210419112151972.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="107031"><img alt="패션 탱고 티 레모네이드 피지오" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[107031]_20210419125349904.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004134"><img alt="그린 애플 캐모마일 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004134]_20220819133555297.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004131"><img alt="아이스 호두 블랙 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004131]_20220819134510460.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004128"><img alt="호두 블랙 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004128]_20220819134408047.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000056"><img alt="민트 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000056]_20210415135215632.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000059"><img alt="아이스 민트 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000059]_20210415141656038.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000039"><img alt="아이스 얼 그레이 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000039]_20210415142055860.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000229"><img alt="아이스 유스베리 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000229]_20210415142219481.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002959"><img alt="아이스 유자 민트 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000002959]_20220411155904911.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000019"><img alt="아이스 잉글리쉬 브렉퍼스트 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000019]_20210415142323353.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="400400000094"><img alt="아이스 제주 유기 녹차" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[400400000094]_20210415230316469.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000079"><img alt="아이스 캐모마일 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000079]_20210415143641139.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000069"><img alt="아이스 히비스커스 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000069]_20210415143811231.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000036"><img alt="얼 그레이 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000036]_20210415143933425.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004116"><img alt="유스베리 로즈 티 브리즈" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004116]_20220418153251099.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000226"><img alt="유스베리 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000226]_20210415144434521.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002956"><img alt="유자 민트 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000002956]_20220411155551915.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000016"><img alt="잉글리쉬 브렉퍼스트 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000016]_20210415153648533.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000187"><img alt="자몽 허니 블랙 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000187]_20210419131229539.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="400400000091"><img alt="제주 유기 녹차" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[400400000091]_20210415132229904.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000076"><img alt="캐모마일 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000076]_20210415154920731.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="4004000000066"><img alt="히비스커스 블렌드 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[4004000000066]_20210415155836395.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004117"><img alt="아이스 유스베리 로즈 티 브리즈" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004117]_20220418153226007.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000000190"><img alt="아이스 자몽 허니 블랙 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000000190]_20210419131723532.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004115"><img alt="제주 그린 티 브리즈" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004115]_20220418153154247.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003998"><img alt="제주 키위 오션 그린티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/03/[9200000003998]_20220311105658286.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004113"><img alt="폼폼 민트 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004113]_20220418153033969.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000004114"><img alt="폼폼 유스베리 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/04/[9200000004114]_20220418153123863.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002963"><img alt="돌체 블랙 밀크 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/02/[9200000002963]_20220203082330522.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002966"><img alt="아이스 돌체 블랙 밀크 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/02/[9200000002966]_20220203082502987.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002499"><img alt="아이스 제주 유기농 말차로 만든 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002499]_20210419130902541.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="135612"><img alt="아이스 차이 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[135612]_20210415142512793.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003234"><img alt="아이스 허니 얼 그레이 밀크 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000003234]_20200911143458239.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002496"><img alt="제주 유기농 말차로 만든 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002496]_20210419131039350.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="135608"><img alt="차이 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[135608]_20210415154244810.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003233"><img alt="허니 얼 그레이 밀크 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000003233]_20200911143800286.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="72"><img alt="시그니처 핫 초콜릿" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[72]_20210415140949967.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="110621"><img alt="아이스 시그니처 초콜릿" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[110621]_20210415140901611.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003658"><img alt="플러피 판다 아이스 초콜릿" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000003658]_20210422080248176.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002594"><img alt="플러피 판다 핫 초콜릿" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000002594]_20210422080327783.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003671"><img alt="레드 파워 스매셔" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/08/[9200000003671]_20210805164103847.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000003659"><img alt="스타벅스 슬래머" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9200000003659]_20210428134252131.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="17"><img alt="스팀 우유" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[17]_20210426095334934.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001302"><img alt="아이스 제주 까망 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000001302]_20200921171804529.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="18"><img alt="우유" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[18]_20210426095514018.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000001301"><img alt="제주 까망 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000001301]_20200921171639781.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9200000002089"><img alt="제주 쑥쑥 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2020/09/[9200000002089]_20200921171510982.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000002853"><img alt="기운내라임 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9300000002853]_20210419104333070.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000002850"><img alt="파이팅 청귤 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9300000002850]_20210419125156886.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000002854"><img alt="한방에 쭉 감당 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9300000002854]_20210419125705500.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008070"><img alt="딸기주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008070]_20210426095034991.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008061"><img alt="망고주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008061]_20210426095229362.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003773"><img alt="스타 루비 자몽 스위트 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003773]_20211020094026246.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003774"><img alt="스타 루비 자몽 스위트 591ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003774]_20211020095032343.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003771"><img alt="유기농 오렌지 100% 주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003771]_20211020093812909.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003772"><img alt="유기농 오렌지 100% 주스 591ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003772]_20211020095105008.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008072"><img alt="케일&amp;사과주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008072]_20210426100712780.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008074"><img alt="토마토주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008074]_20210419112239085.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003776"><img alt="핑크 용과 레모네이드 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003776]_20211020094321785.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008055"><img alt="한라봉주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008055]_20210426102703624.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000002565"><img alt="햇사과 주스 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[9300000002565]_20210426102753285.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000003775"><img alt="딸기 가득 요거트 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/10/[9300000003775]_20211020094208342.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="5210008063"><img alt="블루베리 요거트 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2021/04/[5210008063]_20210419104847612.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000004239"><img alt="애플망고 코코넛 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/06/[9300000004239]_20220628085511020.jpg"/></a>,
#  <a class="goDrinkView" href="javascript:void(0)" prod="9300000004238"><img alt="한라봉 코코넛 190ML" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/06/[9300000004238]_20220628085932263.jpg"/></a>,
#  <a class="goServiceView" f_cate="//W0000001" href="javascript:void(0)" prod="9200000002259"><img alt="블랙 글레이즈드 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000002259]_20220819134201192.jpg"/></a>,
#  <a class="goServiceView" f_cate="//W0000001" href="javascript:void(0)" prod="9200000002262"><img alt="아이스 블랙 글레이즈드 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000002262]_20220819134241498.jpg"/></a>,
#  <a class="goServiceView" f_cate="//W0000001" href="javascript:void(0)" prod="9200000004134"><img alt="그린 애플 캐모마일 티" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004134]_20220819133555297.jpg"/></a>,
#  <a class="goServiceView" f_cate="//W0000001" href="javascript:void(0)" prod="9200000004128"><img alt="호두 블랙 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004128]_20220819134408047.jpg"/></a>,
#  <a class="goServiceView" f_cate="//W0000001" href="javascript:void(0)" prod="9200000004131"><img alt="아이스 호두 블랙 티 라떼" src="https://image.istarbucks.co.kr/upload/store/skuimg/2022/08/[9200000004131]_20220819134510460.jpg"/></a>]

# %%
# 코드, 제품 이름
prod_cd = [[product['prod'], product.find('img')['alt']] for product in products]

pprint(prod_cd)
# Out:
# [['9200000002487', '나이트로 바닐라 크림'],
#  ['9200000000479', '나이트로 콜드 브루'],
#  ['9200000002081', '돌체 콜드 브루'],
#  ['9200000000487', '바닐라 크림 콜드 브루'],
#  ['9200000003509', '벨벳 다크 모카 나이트로'],
#  ['9200000003661', '시그니처 더 블랙 콜드 브루'],
#  ['9200000002672', '제주 비자림 콜드 브루'],
#  ['9200000000038', '콜드 브루'],
#  ['9200000001636', '콜드 브루 몰트'],
#  ['9200000003285', '콜드 브루 오트 라떼'],
#  ['9200000001635', '콜드 브루 플로트'],
#  ['106509', '아이스 커피'],
#  ['2', '오늘의 커피'],
#  ['9200000002259', '블랙 글레이즈드 라떼'],
#  ['9200000002262', '아이스 블랙 글레이즈드 라떼'],
#  ['30', '에스프레소 콘 파나'],
#  ['25', '에스프레소 마키아또'],
#  ['110563', '아이스 카페 아메리카노'],
#  ['94', '카페 아메리카노'],
#  ['110582', '아이스 카라멜 마키아또'],
#  ['126197', '카라멜 마키아또'],
#  ['110601', '아이스 카푸치노'],
#  ['38', '카푸치노'],
#  ['9200000004119', '라벤더 카페 브레베'],
#  ['9200000001086', '럼 샷 코르타도'],
#  ['9200000001939', '바닐라 빈 라떼'],
#  ['9200000002095', '사케라또 비안코 오버 아이스'],
#  ['128692', '스타벅스 돌체 라떼'],
#  ['9200000004120', '아이스 라벤더 카페 브레베'],
#  ['9200000001941', '아이스 바닐라 빈 라떼'],
#  ['128695', '아이스 스타벅스 돌체 라떼'],
#  ['110569', '아이스 카페 라떼'],
#  ['41', '카페 라떼'],
#  ['110566', '아이스 카페 모카'],
#  ['110572', '아이스 화이트 초콜릿 모카'],
#  ['46', '카페 모카'],
#  ['128192', '화이트 초콜릿 모카'],
#  ['9200000002406', '바닐라 플랫 화이트'],
#  ['110612', '바닐라 스타벅스 더블 샷'],
#  ['9200000002950', '블론드 바닐라 더블 샷 마키아또'],
#  ['9200000003505', '사케라또 아포가토'],
#  ['9200000003506', '스파클링 시트러스 에스프레소'],
#  ['9200000002953', '아이스 블론드 바닐라 더블 샷 마키아또'],
#  ['20', '에스프레소'],
#  ['110611', '커피 스타벅스 더블 샷'],
#  ['9200000001631', '클래식 아포가토'],
#  ['110614', '헤이즐넛 스타벅스 더블 샷'],
#  ['9200000002760', '더블 에스프레소 칩 프라푸치노'],
#  ['168004', '모카 프라푸치노'],
#  ['168007', '에스프레소 프라푸치노'],
#  ['168016', '자바 칩 프라푸치노'],
#  ['168010', '카라멜 프라푸치노'],
#  ['168013', '화이트 초콜릿 모카 프라푸치노'],
#  ['168054', '바닐라 크림 프라푸치노'],
#  ['9200000002088', '제주 까망 크림 프라푸치노'],
#  ['9200000002090', '제주 쑥떡 크림 프라푸치노'],
#  ['9200000002502', '제주 유기농 말차로 만든 크림 프라푸치노'],
#  ['168066', '초콜릿 크림 칩 프라푸치노'],
#  ['9200000002403', '화이트 타이거 프라푸치노'],
#  ['167004', '망고 패션 프루트 블렌디드'],
#  ['9200000003276', '딸기 딜라이트 요거트 블렌디드'],
#  ['9200000003660', '레드 파워 스매시 블렌디드'],
#  ['169001', '망고 바나나 블렌디드'],
#  ['9200000003443', '민트 초콜릿 칩 블렌디드'],
#  ['9200000003997', '제주 그린 한라봉 모히또 블렌디드'],
#  ['9200000003763', '딸기 아사이 레모네이드 스타벅스 리프레셔'],
#  ['9200000003766', '핑크 드링크 위드 딸기 아사이 스타벅스 리프레셔'],
#  ['107025', '블랙 티 레모네이드 피지오'],
#  ['9200000004121', '유자 패션 피지오'],
#  ['107051', '쿨 라임 피지오'],
#  ['107031', '패션 탱고 티 레모네이드 피지오'],
#  ['9200000004134', '그린 애플 캐모마일 티'],
#  ['9200000004131', '아이스 호두 블랙 티 라떼'],
#  ['9200000004128', '호두 블랙 티 라떼'],
#  ['4004000000056', '민트 블렌드 티'],
#  ['4004000000059', '아이스 민트 블렌드 티'],
#  ['4004000000039', '아이스 얼 그레이 티'],
#  ['9200000000229', '아이스 유스베리 티'],
#  ['9200000002959', '아이스 유자 민트 티'],
#  ['4004000000019', '아이스 잉글리쉬 브렉퍼스트 티'],
#  ['400400000094', '아이스 제주 유기 녹차'],
#  ['4004000000079', '아이스 캐모마일 블렌드 티'],
#  ['4004000000069', '아이스 히비스커스 블렌드 티'],
#  ['4004000000036', '얼 그레이 티'],
#  ['9200000004116', '유스베리 로즈 티 브리즈'],
#  ['9200000000226', '유스베리 티'],
#  ['9200000002956', '유자 민트 티'],
#  ['4004000000016', '잉글리쉬 브렉퍼스트 티'],
#  ['9200000000187', '자몽 허니 블랙 티'],
#  ['400400000091', '제주 유기 녹차'],
#  ['4004000000076', '캐모마일 블렌드 티'],
#  ['4004000000066', '히비스커스 블렌드 티'],
#  ['9200000004117', '아이스 유스베리 로즈 티 브리즈'],
#  ['9200000000190', '아이스 자몽 허니 블랙 티'],
#  ['9200000004115', '제주 그린 티 브리즈'],
#  ['9200000003998', '제주 키위 오션 그린티'],
#  ['9200000004113', '폼폼 민트 티'],
#  ['9200000004114', '폼폼 유스베리 티'],
#  ['9200000002963', '돌체 블랙 밀크 티'],
#  ['9200000002966', '아이스 돌체 블랙 밀크 티'],
#  ['9200000002499', '아이스 제주 유기농 말차로 만든 라떼'],
#  ['135612', '아이스 차이 티 라떼'],
#  ['9200000003234', '아이스 허니 얼 그레이 밀크 티'],
#  ['9200000002496', '제주 유기농 말차로 만든 라떼'],
#  ['135608', '차이 티 라떼'],
#  ['9200000003233', '허니 얼 그레이 밀크 티'],
#  ['72', '시그니처 핫 초콜릿'],
#  ['110621', '아이스 시그니처 초콜릿'],
#  ['9200000003658', '플러피 판다 아이스 초콜릿'],
#  ['9200000002594', '플러피 판다 핫 초콜릿'],
#  ['9200000003671', '레드 파워 스매셔'],
#  ['9200000003659', '스타벅스 슬래머'],
#  ['17', '스팀 우유'],
#  ['9200000001302', '아이스 제주 까망 라떼'],
#  ['18', '우유'],
#  ['9200000001301', '제주 까망 라떼'],
#  ['9200000002089', '제주 쑥쑥 라떼'],
#  ['9300000002853', '기운내라임 190ML'],
#  ['9300000002850', '파이팅 청귤 190ML'],
#  ['9300000002854', '한방에 쭉 감당 190ML'],
#  ['5210008070', '딸기주스 190ML'],
#  ['5210008061', '망고주스 190ML'],
#  ['9300000003773', '스타 루비 자몽 스위트 190ML'],
#  ['9300000003774', '스타 루비 자몽 스위트 591ML'],
#  ['9300000003771', '유기농 오렌지 100% 주스 190ML'],
#  ['9300000003772', '유기농 오렌지 100% 주스 591ML'],
#  ['5210008072', '케일&사과주스 190ML'],
#  ['5210008074', '토마토주스 190ML'],
#  ['9300000003776', '핑크 용과 레모네이드 190ML'],
#  ['5210008055', '한라봉주스 190ML'],
#  ['9300000002565', '햇사과 주스 190ML'],
#  ['9300000003775', '딸기 가득 요거트 190ML'],
#  ['5210008063', '블루베리 요거트 190ML'],
#  ['9300000004239', '애플망고 코코넛 190ML'],
#  ['9300000004238', '한라봉 코코넛 190ML'],
#  ['9200000002259', '블랙 글레이즈드 라떼'],
#  ['9200000002262', '아이스 블랙 글레이즈드 라떼'],
#  ['9200000004134', '그린 애플 캐모마일 티'],
#  ['9200000004128', '호두 블랙 티 라떼'],
#  ['9200000004131', '아이스 호두 블랙 티 라떼']]

# %%
import time

result = []

for prod in prod_cd:
    container = dict()
    cd = prod[0]
    name = prod[1]
    
    browser.get(f"https://www.starbucks.co.kr/menu/drink_view.do?product_cd={cd}")
    html = browser.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 용량
    volume = soup.select_one('.product_info_head #product_info01').get_text()
    
    # 제품 영양 정보
    cateL = soup.select_one('.smap .cate').get_text()
    kcal = soup.select_one('.product_info_content .kcal dd').get_text()
    sat_FAT = soup.select_one('.product_info_content .sat_FAT dd').get_text()    
    protein = soup.select_one('.product_info_content .protein dd').get_text()    
    fat = soup.select_one('.product_info_content .fat dd').get_text()    
    trans_FAT = soup.select_one('.product_info_content .trans_FAT dd').get_text()    
    sodium = soup.select_one('.product_info_content .sodium dd').get_text()    
    sugars = soup.select_one('.product_info_content .sugars dd').get_text()    
    caffeine = soup.select_one('.product_info_content .caffeine dd').get_text()    
    cholesterol = soup.select_one('.product_info_content .cholesterol dd').get_text()    

    container['분류'] = cateL
    container['1회 제공량'] = volume
    container['메뉴'] = name
    container['칼로리(kcal)'] = kcal
    container['당류(g)'] = sugars
    container['단백질(g)'] = protein
    container['나트륨(mg)'] = sodium
    container['포화지방(g)'] = sat_FAT
    container['카페인(mg)'] = caffeine
    
    result.append(container)
    
    time.sleep(3)

# %%
pprint(result)
# Out:
# [{'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '40',
#   '단백질(g)': '1',
#   '당류(g)': '10',
#   '메뉴': '나이트로 바닐라 크림',
#   '분류': '콜드 브루',
#   '카페인(mg)': '232',
#   '칼로리(kcal)': '80',
#   '포화지방(g)': '2'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '나이트로 콜드 브루',
#   '분류': '콜드 브루',
#   '카페인(mg)': '245',
#   '칼로리(kcal)': '5',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '130',
#   '단백질(g)': '8',
#   '당류(g)': '29',
#   '메뉴': '돌체 콜드 브루',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '265',
#   '포화지방(g)': '9'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '58',
#   '단백질(g)': '3',
#   '당류(g)': '11',
#   '메뉴': '바닐라 크림 콜드 브루',
#   '분류': '콜드 브루',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '15',
#   '단백질(g)': '2',
#   '당류(g)': '17',
#   '메뉴': '벨벳 다크 모카 나이트로',
#   '분류': '콜드 브루',
#   '카페인(mg)': '190',
#   '칼로리(kcal)': '150',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Bottle(보틀) / 500ml (17 fl oz)',
#   '나트륨(mg)': '50',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '시그니처 더 블랙 콜드 브루',
#   '분류': '콜드 브루',
#   '카페인(mg)': '680',
#   '칼로리(kcal)': '25',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '140',
#   '단백질(g)': '10',
#   '당류(g)': '43',
#   '메뉴': '제주 비자림 콜드 브루',
#   '분류': '콜드 브루',
#   '카페인(mg)': '105',
#   '칼로리(kcal)': '340',
#   '포화지방(g)': '8'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '11',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '콜드 브루',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '5',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '7',
#   '당류(g)': '41',
#   '메뉴': '콜드 브루 몰트',
#   '분류': '콜드 브루',
#   '카페인(mg)': '190',
#   '칼로리(kcal)': '505',
#   '포화지방(g)': '20'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '95',
#   '단백질(g)': '1',
#   '당류(g)': '14',
#   '메뉴': '콜드 브루 오트 라떼',
#   '분류': '콜드 브루',
#   '카페인(mg)': '65',
#   '칼로리(kcal)': '120',
#   '포화지방(g)': '0.3'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '3',
#   '당류(g)': '18',
#   '메뉴': '콜드 브루 플로트',
#   '분류': '콜드 브루',
#   '카페인(mg)': '190',
#   '칼로리(kcal)': '225',
#   '포화지방(g)': '10'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 커피',
#   '분류': '브루드 커피',
#   '카페인(mg)': '140',
#   '칼로리(kcal)': '5',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '오늘의 커피',
#   '분류': '브루드 커피',
#   '카페인(mg)': '260',
#   '칼로리(kcal)': '5',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '220',
#   '단백질(g)': '11',
#   '당류(g)': '37',
#   '메뉴': '블랙 글레이즈드 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '385',
#   '포화지방(g)': '14'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '160',
#   '단백질(g)': '7',
#   '당류(g)': '31',
#   '메뉴': '아이스 블랙 글레이즈드 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '305',
#   '포화지방(g)': '11'},
#  {'1회 제공량': 'Solo(솔로) / 22ml (0.75 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '1',
#   '메뉴': '에스프레소 콘 파나',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '30',
#   '포화지방(g)': '1.5'},
#  {'1회 제공량': 'Solo(솔로) / 22ml (0.75 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '1',
#   '당류(g)': '0',
#   '메뉴': '에스프레소 마키아또',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '10',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '1',
#   '당류(g)': '0',
#   '메뉴': '아이스 카페 아메리카노',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '10',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '1',
#   '당류(g)': '0',
#   '메뉴': '카페 아메리카노',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '10',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '110',
#   '단백질(g)': '6',
#   '당류(g)': '22',
#   '메뉴': '아이스 카라멜 마키아또',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '190',
#   '포화지방(g)': '4.6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '130',
#   '단백질(g)': '8',
#   '당류(g)': '22',
#   '메뉴': '카라멜 마키아또',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '200',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '90',
#   '단백질(g)': '6',
#   '당류(g)': '9',
#   '메뉴': '아이스 카푸치노',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '115',
#   '포화지방(g)': '3.5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '6',
#   '당류(g)': '8',
#   '메뉴': '카푸치노',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '110',
#   '포화지방(g)': '3'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '140',
#   '단백질(g)': '8',
#   '당류(g)': '30',
#   '메뉴': '라벤더 카페 브레베',
#   '분류': '에스프레소',
#   '카페인(mg)': '105',
#   '칼로리(kcal)': '400',
#   '포화지방(g)': '22'},
#  {'1회 제공량': 'Short(숏) / 237ml (8 fl oz)',
#   '나트륨(mg)': '45',
#   '단백질(g)': '3',
#   '당류(g)': '8',
#   '메뉴': '럼 샷 코르타도',
#   '분류': '에스프레소',
#   '카페인(mg)': '160',
#   '칼로리(kcal)': '70',
#   '포화지방(g)': '1.8'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '9',
#   '당류(g)': '27',
#   '메뉴': '바닐라 빈 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '210',
#   '칼로리(kcal)': '245',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '45',
#   '단백질(g)': '3',
#   '당류(g)': '14',
#   '메뉴': '사케라또 비안코 오버 아이스',
#   '분류': '에스프레소',
#   '카페인(mg)': '315',
#   '칼로리(kcal)': '270',
#   '포화지방(g)': '18'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '190',
#   '단백질(g)': '12',
#   '당류(g)': '39',
#   '메뉴': '스타벅스 돌체 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '255',
#   '포화지방(g)': '2.6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '110',
#   '단백질(g)': '6',
#   '당류(g)': '27',
#   '메뉴': '아이스 라벤더 카페 브레베',
#   '분류': '에스프레소',
#   '카페인(mg)': '105',
#   '칼로리(kcal)': '335',
#   '포화지방(g)': '18'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '75',
#   '단백질(g)': '5',
#   '당류(g)': '20',
#   '메뉴': '아이스 바닐라 빈 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '210',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '2.9'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '145',
#   '단백질(g)': '10',
#   '당류(g)': '35',
#   '메뉴': '아이스 스타벅스 돌체 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '230',
#   '포화지방(g)': '2.5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '75',
#   '단백질(g)': '6',
#   '당류(g)': '8',
#   '메뉴': '아이스 카페 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '110',
#   '포화지방(g)': '3.5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '115',
#   '단백질(g)': '10',
#   '당류(g)': '13',
#   '메뉴': '카페 라떼',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '180',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '7',
#   '당류(g)': '21',
#   '메뉴': '아이스 카페 모카',
#   '분류': '에스프레소',
#   '카페인(mg)': '95',
#   '칼로리(kcal)': '250',
#   '포화지방(g)': '8'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '75',
#   '단백질(g)': '7',
#   '당류(g)': '27',
#   '메뉴': '아이스 화이트 초콜릿 모카',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '260',
#   '포화지방(g)': '8'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '105',
#   '단백질(g)': '10',
#   '당류(g)': '25',
#   '메뉴': '카페 모카',
#   '분류': '에스프레소',
#   '카페인(mg)': '95',
#   '칼로리(kcal)': '290',
#   '포화지방(g)': '9'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '11',
#   '당류(g)': '35',
#   '메뉴': '화이트 초콜릿 모카',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '345',
#   '포화지방(g)': '11'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '130',
#   '단백질(g)': '9',
#   '당류(g)': '23',
#   '메뉴': '바닐라 플랫 화이트',
#   '분류': '에스프레소',
#   '카페인(mg)': '260',
#   '칼로리(kcal)': '220',
#   '포화지방(g)': '5'},
#  {'1회 제공량': '207ml (7 fl oz)',
#   '나트륨(mg)': '30',
#   '단백질(g)': '2',
#   '당류(g)': '14',
#   '메뉴': '바닐라 스타벅스 더블 샷',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '4.5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '130',
#   '단백질(g)': '8',
#   '당류(g)': '31',
#   '메뉴': '블론드 바닐라 더블 샷 마키아또',
#   '분류': '에스프레소',
#   '카페인(mg)': '170',
#   '칼로리(kcal)': '315',
#   '포화지방(g)': '12'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '4',
#   '당류(g)': '30',
#   '메뉴': '사케라또 아포가토',
#   '분류': '에스프레소',
#   '카페인(mg)': '210',
#   '칼로리(kcal)': '290',
#   '포화지방(g)': '10'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '15',
#   '메뉴': '스파클링 시트러스 에스프레소',
#   '분류': '에스프레소',
#   '카페인(mg)': '105',
#   '칼로리(kcal)': '65',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '65',
#   '단백질(g)': '5',
#   '당류(g)': '22',
#   '메뉴': '아이스 블론드 바닐라 더블 샷 마키아또',
#   '분류': '에스프레소',
#   '카페인(mg)': '170',
#   '칼로리(kcal)': '195',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Solo(솔로) / 22ml (0.75 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '에스프레소',
#   '분류': '에스프레소',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '5',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '207ml (7 fl oz)',
#   '나트륨(mg)': '28.5',
#   '단백질(g)': '3',
#   '당류(g)': '14',
#   '메뉴': '커피 스타벅스 더블 샷',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '4',
#   '당류(g)': '18',
#   '메뉴': '클래식 아포가토',
#   '분류': '에스프레소',
#   '카페인(mg)': '210',
#   '칼로리(kcal)': '240',
#   '포화지방(g)': '10'},
#  {'1회 제공량': '207ml (7 fl oz)',
#   '나트륨(mg)': '28.5',
#   '단백질(g)': '3',
#   '당류(g)': '14',
#   '메뉴': '헤이즐넛 스타벅스 더블 샷',
#   '분류': '에스프레소',
#   '카페인(mg)': '150',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '140',
#   '단백질(g)': '4',
#   '당류(g)': '31',
#   '메뉴': '더블 에스프레소 칩 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '130',
#   '칼로리(kcal)': '265',
#   '포화지방(g)': '11'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '180',
#   '단백질(g)': '5',
#   '당류(g)': '36',
#   '메뉴': '모카 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '90',
#   '칼로리(kcal)': '280',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '115',
#   '단백질(g)': '2',
#   '당류(g)': '29',
#   '메뉴': '에스프레소 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '120',
#   '칼로리(kcal)': '145',
#   '포화지방(g)': '1.1'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '180',
#   '단백질(g)': '6',
#   '당류(g)': '42',
#   '메뉴': '자바 칩 프라푸치노',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '100',
#   '칼로리(kcal)': '340',
#   '포화지방(g)': '9'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '190',
#   '단백질(g)': '4',
#   '당류(g)': '39',
#   '메뉴': '카라멜 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '85',
#   '칼로리(kcal)': '300',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '140',
#   '단백질(g)': '4',
#   '당류(g)': '38',
#   '메뉴': '화이트 초콜릿 모카 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '85',
#   '칼로리(kcal)': '245',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '4',
#   '당류(g)': '28',
#   '메뉴': '바닐라 크림 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '200',
#   '포화지방(g)': '6'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '330',
#   '단백질(g)': '9',
#   '당류(g)': '79',
#   '메뉴': '제주 까망 크림 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '600',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '250',
#   '단백질(g)': '8',
#   '당류(g)': '57',
#   '메뉴': '제주 쑥떡 크림 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '460',
#   '포화지방(g)': '10'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '5',
#   '당류(g)': '28',
#   '메뉴': '제주 유기농 말차로 만든 크림 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '60',
#   '칼로리(kcal)': '230',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '160',
#   '단백질(g)': '6',
#   '당류(g)': '40',
#   '메뉴': '초콜릿 크림 칩 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '10',
#   '칼로리(kcal)': '300',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '220',
#   '단백질(g)': '5',
#   '당류(g)': '57',
#   '메뉴': '화이트 타이거 프라푸치노',
#   '분류': '프라푸치노',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '410',
#   '포화지방(g)': '14'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '1',
#   '당류(g)': '25',
#   '메뉴': '망고 패션 프루트 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '35',
#   '칼로리(kcal)': '120',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '110',
#   '단백질(g)': '9',
#   '당류(g)': '57',
#   '메뉴': '딸기 딜라이트 요거트 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '370',
#   '포화지방(g)': '4.3'},
#  {'1회 제공량': '',
#   '나트륨(mg)': '30',
#   '단백질(g)': '1',
#   '당류(g)': '49',
#   '메뉴': '레드 파워 스매시 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '17',
#   '칼로리(kcal)': '270',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '110',
#   '단백질(g)': '4',
#   '당류(g)': '48',
#   '메뉴': '망고 바나나 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '270',
#   '포화지방(g)': '1'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '190',
#   '단백질(g)': '9',
#   '당류(g)': '52',
#   '메뉴': '민트 초콜릿 칩 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '455',
#   '포화지방(g)': '14'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '37',
#   '메뉴': '제주 그린 한라봉 모히또 블렌디드',
#   '분류': '블렌디드',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '160',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '1',
#   '당류(g)': '24',
#   '메뉴': '딸기 아사이 레모네이드 스타벅스 리프레셔',
#   '분류': '스타벅스 리프레셔',
#   '카페인(mg)': '30',
#   '칼로리(kcal)': '105',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '40',
#   '단백질(g)': '1',
#   '당류(g)': '18',
#   '메뉴': '핑크 드링크 위드 딸기 아사이 스타벅스 리프레셔',
#   '분류': '스타벅스 리프레셔',
#   '카페인(mg)': '30',
#   '칼로리(kcal)': '100',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '17',
#   '메뉴': '블랙 티 레모네이드 피지오',
#   '분류': '스타벅스 피지오',
#   '카페인(mg)': '30',
#   '칼로리(kcal)': '65',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '36',
#   '메뉴': '유자 패션 피지오',
#   '분류': '스타벅스 피지오',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '145',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '20',
#   '단백질(g)': '0',
#   '당류(g)': '25',
#   '메뉴': '쿨 라임 피지오',
#   '분류': '스타벅스 피지오',
#   '카페인(mg)': '110',
#   '칼로리(kcal)': '105',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0.2',
#   '단백질(g)': '0',
#   '당류(g)': '17',
#   '메뉴': '패션 탱고 티 레모네이드 피지오',
#   '분류': '스타벅스 피지오',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '65',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '15',
#   '단백질(g)': '0',
#   '당류(g)': '37',
#   '메뉴': '그린 애플 캐모마일 티',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '95',
#   '단백질(g)': '3',
#   '당류(g)': '26',
#   '메뉴': '아이스 호두 블랙 티 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '15',
#   '칼로리(kcal)': '245',
#   '포화지방(g)': '4.7'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '190',
#   '단백질(g)': '4',
#   '당류(g)': '29',
#   '메뉴': '호두 블랙 티 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '320',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '민트 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 민트 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 얼 그레이 티',
#   '분류': '티',
#   '카페인(mg)': '50',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 유스베리 티',
#   '분류': '티',
#   '카페인(mg)': '20',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '37',
#   '메뉴': '아이스 유자 민트 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '145',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 잉글리쉬 브렉퍼스트 티',
#   '분류': '티',
#   '카페인(mg)': '40',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 제주 유기 녹차',
#   '분류': '티',
#   '카페인(mg)': '16',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 캐모마일 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '아이스 히비스커스 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '얼 그레이 티',
#   '분류': '티',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '20',
#   '단백질(g)': '0',
#   '당류(g)': '38',
#   '메뉴': '유스베리 로즈 티 브리즈',
#   '분류': '티',
#   '카페인(mg)': '20',
#   '칼로리(kcal)': '165',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '유스베리 티',
#   '분류': '티',
#   '카페인(mg)': '20',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0',
#   '당류(g)': '58',
#   '메뉴': '유자 민트 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '235',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '잉글리쉬 브렉퍼스트 티',
#   '분류': '티',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '30',
#   '메뉴': '자몽 허니 블랙 티',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '제주 유기 녹차',
#   '분류': '티',
#   '카페인(mg)': '16',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '캐모마일 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '0',
#   '메뉴': '히비스커스 블렌드 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '0',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '15',
#   '단백질(g)': '0',
#   '당류(g)': '27',
#   '메뉴': '아이스 유스베리 로즈 티 브리즈',
#   '분류': '티',
#   '카페인(mg)': '12',
#   '칼로리(kcal)': '120',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '30',
#   '메뉴': '아이스 자몽 허니 블랙 티',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '30',
#   '칼로리(kcal)': '125',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '31',
#   '메뉴': '제주 그린 티 브리즈',
#   '분류': '티',
#   '카페인(mg)': '42',
#   '칼로리(kcal)': '220',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '15',
#   '단백질(g)': '0',
#   '당류(g)': '37',
#   '메뉴': '제주 키위 오션 그린티',
#   '분류': '티',
#   '카페인(mg)': '10',
#   '칼로리(kcal)': '195',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '42',
#   '메뉴': '폼폼 민트 티',
#   '분류': '티',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '210',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '42',
#   '메뉴': '폼폼 유스베리 티',
#   '분류': '티',
#   '카페인(mg)': '10',
#   '칼로리(kcal)': '210',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '115',
#   '단백질(g)': '8',
#   '당류(g)': '34',
#   '메뉴': '돌체 블랙 밀크 티',
#   '분류': '티',
#   '카페인(mg)': '60',
#   '칼로리(kcal)': '250',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '85',
#   '단백질(g)': '6',
#   '당류(g)': '31',
#   '메뉴': '아이스 돌체 블랙 밀크 티',
#   '분류': '티',
#   '카페인(mg)': '35',
#   '칼로리(kcal)': '210',
#   '포화지방(g)': '3.7'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '95',
#   '단백질(g)': '6',
#   '당류(g)': '16',
#   '메뉴': '아이스 제주 유기농 말차로 만든 라떼',
#   '분류': '티',
#   '카페인(mg)': '60',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '3.6'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '5',
#   '당류(g)': '31',
#   '메뉴': '아이스 차이 티 라떼',
#   '분류': '티',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '190',
#   '포화지방(g)': '3'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '65',
#   '단백질(g)': '4',
#   '당류(g)': '31',
#   '메뉴': '아이스 허니 얼 그레이 밀크 티',
#   '분류': '티',
#   '카페인(mg)': '52',
#   '칼로리(kcal)': '220',
#   '포화지방(g)': '2.4'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '130',
#   '단백질(g)': '9',
#   '당류(g)': '20',
#   '메뉴': '제주 유기농 말차로 만든 라떼',
#   '분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)',
#   '카페인(mg)': '60',
#   '칼로리(kcal)': '205',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '6',
#   '당류(g)': '31',
#   '메뉴': '차이 티 라떼',
#   '분류': '티',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '200',
#   '포화지방(g)': '3'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '210',
#   '단백질(g)': '12',
#   '당류(g)': '45',
#   '메뉴': '허니 얼 그레이 밀크 티',
#   '분류': '티',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '395',
#   '포화지방(g)': '8'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '105',
#   '단백질(g)': '15',
#   '당류(g)': '52',
#   '메뉴': '시그니처 핫 초콜릿',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '15',
#   '칼로리(kcal)': '500',
#   '포화지방(g)': '9'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '70',
#   '단백질(g)': '10',
#   '당류(g)': '32',
#   '메뉴': '아이스 시그니처 초콜릿',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '15',
#   '칼로리(kcal)': '325',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '150',
#   '단백질(g)': '11',
#   '당류(g)': '39',
#   '메뉴': '플러피 판다 아이스 초콜릿',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '415',
#   '포화지방(g)': '16'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '160',
#   '단백질(g)': '12',
#   '당류(g)': '48',
#   '메뉴': '플러피 판다 핫 초콜릿',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '470',
#   '포화지방(g)': '17'},
#  {'1회 제공량': '',
#   '나트륨(mg)': '40',
#   '단백질(g)': '1',
#   '당류(g)': '67',
#   '메뉴': '레드 파워 스매셔',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '25',
#   '칼로리(kcal)': '370',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '0',
#   '단백질(g)': '0',
#   '당류(g)': '55',
#   '메뉴': '스타벅스 슬래머',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '235',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '173',
#   '단백질(g)': '13',
#   '당류(g)': '18',
#   '메뉴': '스팀 우유',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '215',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '210',
#   '단백질(g)': '10',
#   '당류(g)': '45',
#   '메뉴': '아이스 제주 까망 라떼',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '440',
#   '포화지방(g)': '11'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '200',
#   '단백질(g)': '12',
#   '당류(g)': '18',
#   '메뉴': '우유',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '240',
#   '포화지방(g)': '8'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '250',
#   '단백질(g)': '13',
#   '당류(g)': '49',
#   '메뉴': '제주 까망 라떼',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '445',
#   '포화지방(g)': '7'},
#  {'1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)',
#   '나트륨(mg)': '210',
#   '단백질(g)': '16',
#   '당류(g)': '50',
#   '메뉴': '제주 쑥쑥 라떼',
#   '분류': '기타 제조 음료',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '425',
#   '포화지방(g)': '9'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '5',
#   '단백질(g)': '1',
#   '당류(g)': '22',
#   '메뉴': '기운내라임 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '90',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '5',
#   '단백질(g)': '1',
#   '당류(g)': '22',
#   '메뉴': '파이팅 청귤 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '95',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '10',
#   '단백질(g)': '1',
#   '당류(g)': '23',
#   '메뉴': '한방에 쭉 감당 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '100',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '30',
#   '단백질(g)': '0',
#   '당류(g)': '25',
#   '메뉴': '딸기주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '110',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '15',
#   '단백질(g)': '1',
#   '당류(g)': '23',
#   '메뉴': '망고주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '117',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0.2',
#   '당류(g)': '32',
#   '메뉴': '스타 루비 자몽 스위트 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '129',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '591 ml',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0.6',
#   '당류(g)': '100',
#   '메뉴': '스타 루비 자몽 스위트 591ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '406',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '5',
#   '단백질(g)': '2',
#   '당류(g)': '20',
#   '메뉴': '유기농 오렌지 100% 주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '95',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '591 ml',
#   '나트륨(mg)': '10',
#   '단백질(g)': '6',
#   '당류(g)': '62',
#   '메뉴': '유기농 오렌지 100% 주스 591ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '290',
#   '포화지방(g)': '0.6'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '25',
#   '단백질(g)': '0',
#   '당류(g)': '26',
#   '메뉴': '케일&사과주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '105',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '120',
#   '단백질(g)': '1',
#   '당류(g)': '16',
#   '메뉴': '토마토주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '70',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '5',
#   '단백질(g)': '0',
#   '당류(g)': '19',
#   '메뉴': '핑크 용과 레모네이드 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '88',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0.5',
#   '당류(g)': '16',
#   '메뉴': '한라봉주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '78',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '10',
#   '단백질(g)': '0.2',
#   '당류(g)': '27',
#   '메뉴': '햇사과 주스 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '113',
#   '포화지방(g)': '0'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '50',
#   '단백질(g)': '4',
#   '당류(g)': '21',
#   '메뉴': '딸기 가득 요거트 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '3.2'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '70',
#   '단백질(g)': '5',
#   '당류(g)': '18',
#   '메뉴': '블루베리 요거트 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '3.6'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '9',
#   '단백질(g)': '3',
#   '당류(g)': '21',
#   '메뉴': '애플망고 코코넛 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '244',
#   '포화지방(g)': '11'},
#  {'1회 제공량': '190 ml',
#   '나트륨(mg)': '9',
#   '단백질(g)': '3',
#   '당류(g)': '19',
#   '메뉴': '한라봉 코코넛 190ML',
#   '분류': '스타벅스 주스(병음료)',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '236',
#   '포화지방(g)': '10'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '220',
#   '단백질(g)': '11',
#   '당류(g)': '37',
#   '메뉴': '블랙 글레이즈드 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '385',
#   '포화지방(g)': '14'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '160',
#   '단백질(g)': '7',
#   '당류(g)': '31',
#   '메뉴': '아이스 블랙 글레이즈드 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '75',
#   '칼로리(kcal)': '305',
#   '포화지방(g)': '11'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '15',
#   '단백질(g)': '0',
#   '당류(g)': '37',
#   '메뉴': '그린 애플 캐모마일 티',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '0',
#   '칼로리(kcal)': '155',
#   '포화지방(g)': '0'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '190',
#   '단백질(g)': '4',
#   '당류(g)': '29',
#   '메뉴': '호두 블랙 티 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '70',
#   '칼로리(kcal)': '320',
#   '포화지방(g)': '5'},
#  {'1회 제공량': 'Tall(톨) / 355ml (12 fl oz)',
#   '나트륨(mg)': '95',
#   '단백질(g)': '3',
#   '당류(g)': '26',
#   '메뉴': '아이스 호두 블랙 티 라떼',
#   '분류': '2022 Autumn',
#   '카페인(mg)': '15',
#   '칼로리(kcal)': '245',
#   '포화지방(g)': '4.7'}]

# %%
print(result)
# Out:
# [{'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '나이트로 바닐라 크림', '칼로리(kcal)': '80', '당류(g)': '10', '단백질(g)': '1', '나트륨(mg)': '40', '포화지방(g)': '2', '카페인(mg)': '232'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '나이트로 콜드 브루', '칼로리(kcal)': '5', '당류(g)': '0', '단백질(g)': '0', '나트륨(mg)': '5', '포화지방(g)': '0', '카페인(mg)': '245'}, {'분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '돌체 콜드 브루', '칼로리(kcal)': '265', '당류(g)': '29', '단백질(g)': '8', '나트륨(mg)': '130', '포화지방(g)': '9', '카페인(mg)': '150'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '바닐라 크림 콜드 브루', '칼로리(kcal)': '125', '당류(g)': '11', '단백질(g)': '3', '나트륨(mg)': '58', '포화지방(g)': '6', '카페인(mg)': '150'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '벨벳 다크 모카 나이트로', '칼로리(kcal)': '150', '당류(g)': '17', '단백질(g)': '2', '나트륨(mg)': '15', '포화지방(g)': '6', '카페인(mg)': '190'}, {'분류': '콜드 브루', '1회 제공량': 'Bottle(보틀) / 500ml (17 fl oz)', '메뉴': '시그니처 더 블랙 콜드 브루', '칼로리(kcal)': '25', '당류(g)': '0', '단백질(g)': '0', '나트륨(mg)': '50', '포화지방(g)': '0', '카페인(mg)': '680'}, {'분류': '콜드 브루', '1회 제공량': 'Grande(그란데) / 473ml (16 fl oz)', '메뉴': '제주 비자림 콜드 브루', '칼로리(kcal)': '340', '당류(g)': '43', '단백질(g)': '10', '나트륨(mg)': '140', '포화지방(g)': '8', '카페인(mg)': '105'}, {'분류': '웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '콜드 브루', '칼로리(kcal)': '5', '당류(g)': '0', '단백질(g)': '0', '나트륨(mg)': '11', '포화지방(g)': '0', '카페인(mg)': '150'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '콜드 브루 몰트', '칼로리(kcal)': '505', '당류(g)': '41', '단백질(g)': '7', '나트륨(mg)': '150', '포화지방(g)': '20', '카페인(mg)': '190'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '콜드 브루 오트 라떼', '칼로리(kcal)': '120', '당류(g)': '14', '단백질(g)': '1', '나트륨(mg)': '95', '포화지방(g)': '0.3', '카페인(mg)': '65'}, {'분류': '콜드 브루', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '콜드 브루 플로트', '칼로리(kcal)': '225', '당류(g)': '18', '단백질(g)': '3', '나트륨(mg)': '70', '포화지방(g)': '10', '카페인(mg)': '190'}, {'분류': '브루드 커피', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '아이스 커피', '칼로리(kcal)': '5', '당류(g)': '0', '단백질(g)': '0', '나트륨(mg)': '10', '포화지방(g)': '0', '카페인(mg)': '140'}, {'분류': '브루드 커피', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '오늘의 커피', '칼로리(kcal)': '5', '당류(g)': '0', '단백질(g)': '0', '나트륨(mg)': '10', '포화지방(g)': '0', '카페인(mg)': '260'}, {'분류': '2022 Autumn', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '블랙 글레이즈드 라떼', '칼로리(kcal)': '385', '당류(g)': '37', '단백질(g)': '11', '나트륨(mg)': '220', '포화지방(g)': '14', '카페인(mg)': '75'}, {'분류': '2022 Autumn', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '아이스 블랙 글레이즈드 라떼', '칼로리(kcal)': '305', '당류(g)': '31', '단백질(g)': '7', '나트륨(mg)': '160', '포화지방(g)': '11', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Solo(솔로) / 22ml (0.75 fl oz)', '메뉴': '에스프레소 콘 파나', '칼로리(kcal)': '30', '당류(g)': '1', '단백질(g)': '0', '나트륨(mg)': '0', '포화지방(g)': '1.5', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Solo(솔로) / 22ml (0.75 fl oz)', '메뉴': '에스프레소 마키아또', '칼로리(kcal)': '10', '당류(g)': '0', '단백질(g)': '1', '나트륨(mg)': '0', '포화지방(g)': '0', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '아이스 카페 아메리카노', '칼로리(kcal)': '10', '당류(g)': '0', '단백질(g)': '1', '나트륨(mg)': '5', '포화지방(g)': '0', '카페인(mg)': '150'}, {'분류': '에스프레소', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '카페 아메리카노', '칼로리(kcal)': '10', '당류(g)': '0', '단백질(g)': '1', '나트륨(mg)': '5', '포화지방(g)': '0', '카페인(mg)': '150'}, {'분류': '에스프레소', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '아이스 카라멜 마키아또', '칼로리(kcal)': '190', '당류(g)': '22', '단백질(g)': '6', '나트륨(mg)': '110', '포화지방(g)': '4.6', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '카라멜 마키아또', '칼로리(kcal)': '200', '당류(g)': '22', '단백질(g)': '8', '나트륨(mg)': '130', '포화지방(g)': '5', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Tall(톨) / 355ml (12 fl oz)', '메뉴': '아이스 카푸치노', '칼로리(kcal)': '115', '당류(g)': '9', '단백질(g)': '6', '나트륨(mg)': '90', '포화지방(g)': '3.5', '카페인(mg)': '75'}, {'분류': '에스프레소', '1회 제공량': 'Tall( ...

# %%
import pandas as pd

df = pd.DataFrame(result)
df.to_csv('./starbucks.csv', index = False, encoding="utf-8-sig")

df
# Out:
#                              분류                      1회 제공량               메뉴  \
# 0                         콜드 브루  Tall(톨) / 355ml (12 fl oz)      나이트로 바닐라 크림
# 1                         콜드 브루  Tall(톨) / 355ml (12 fl oz)       나이트로 콜드 브루
# 2    웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)  Tall(톨) / 355ml (12 fl oz)         돌체 콜드 브루
# 3                         콜드 브루  Tall(톨) / 355ml (12 fl oz)     바닐라 크림 콜드 브루
# 4                         콜드 브루  Tall(톨) / 355ml (12 fl oz)    벨벳 다크 모카 나이트로
# ..                          ...                         ...              ...
# 135                 2022 Autumn  Tall(톨) / 355ml (12 fl oz)      블랙 글레이즈드 라떼
# 136                 2022 Autumn  Tall(톨) / 355ml (12 fl oz)  아이스 블랙 글레이즈드 라떼
# 137                 2022 Autumn  Tall(톨) / 355ml (12 fl oz)     그린 애플 캐모마일 티
# 138                 2022 Autumn  Tall(톨) / 355ml (12 fl oz)       호두 블랙 티 라떼
# 139                 2022 Autumn  Tall(톨) / 355ml (12 fl oz)   아이스 호두 블랙 티 라떼
#
#     칼로리(kcal) 당류(g) 단백질(g) 나트륨(mg) 포화지방(g) 카페인(mg)
# 0          80    10      1      40       2     232
# 1           5     0      0       5       0     245
# 2         265    29      8     130       9     150
# 3         125    11      3      58       6     150
# 4         150    17      2      15       6     190
# ..        ...   ...    ...     ...     ...     ...
# 135       385    37     11     220      14      75
# 136       305    31      7     160      11      75
# 137       155    37      0      15       0       0
# 138       320    29      4     190       5      70
# 139       245    26      3      95     4.7      15
#
# [140 rows x 9 columns]

# %%
browser.quit()

# %%
df
# Out:
#                              분류                          1회 제공량  \
# 0                         콜드 브루      Tall(톨) / 355ml (12 fl oz)
# 1                         콜드 브루      Tall(톨) / 355ml (12 fl oz)
# 2    웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)      Tall(톨) / 355ml (12 fl oz)
# 3                         콜드 브루      Tall(톨) / 355ml (12 fl oz)
# 4                         콜드 브루      Tall(톨) / 355ml (12 fl oz)
# ..                          ...                             ...
# 101  웹사이트 비노출 메뉴(사이렌오더 영양정보 연동)      Tall(톨) / 355ml (12 fl oz)
# 102                           티      Tall(톨) / 355ml (12 fl oz)
# 103                           티  Grande(그란데) / 473ml (16 fl oz)
# 104               2022 Summer 2      Tall(톨) / 355ml (12 fl oz)
# 105                    기타 제조 음료      Tall(톨) / 355ml (12 fl oz)
#
#                    메뉴 칼로리(kcal) 당류(g) 단백질(g) 나트륨(mg) 포화지방(g) 카페인(mg)
# 0         나이트로 바닐라 크림        80    10      1      40       2     232
# 1          나이트로 콜드 브루         5     0      0       5       0     245
# 2            돌체 콜드 브루       265    29      8     130       9     150
# 3        바닐라 크림 콜드 브루       125    11      3      58       6     150
# 4       벨벳 다크 모카 나이트로       150    17      2      15       6     190
# ..                ...       ...   ...    ...     ...     ...     ...
# 101  제주 유기농 말차로 만든 라떼       205    20      9     130       5      60
# 102           차이 티 라떼       200    31      6      70       3      70
# 103     허니 얼 그레이 밀크 티       395    45     12     210       8      70
# 104      제주 청귤 라임 에이드       185    37      0      65       0       0
# 105        시그니처 핫 초콜릿       500    52     15     105       9      15
#
# [106 rows x 9 columns]
